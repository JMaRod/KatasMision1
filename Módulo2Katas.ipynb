# %% [markdown]
# # Ruta donde se va a guardar el entorno
#
#             C:\CursoIntroPython-main\Módulo 2 - Crear y administrar proyectos>

# %% [markdown]
# # Llamando al modulo venv
#                 C:\CursoIntroPython-main\Módulo 2 - Crear y administrar proyectos>python3 -m venv env

# %% [markdown]
# # Activar entorno virtual
#         Use este >env\scripts\activate.bat porque no funciono env\bin\activate
#
#         ya actiavo se ve así la terminal (env) C:\CursoIntroPython-main\Módulo 2 - Crear y administrar proyectos>

# %% [markdown]
# # Instalando python-dateutil

# %% [markdown]
#     Despues de usar el comando  pip install python-dateutil
#
#
#         Collecting python-dateutil
#           Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#         Collecting six>=1.5
#           Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
#         Installing collected packages: six, python-dateutil
#         Successfully installed python-dateutil-2.8.2 six-1.16.0
#         WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
#         You should consider upgrading via the 'C:\CursoIntroPython-main\Módulo 2 - Crear y administrar proyectos\env\Scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Usando pip freeze
#
#     python-dateutil==2.8.2
#     six==1.16.0

# %% [markdown]
# # Desactivando entorno
#
#     tenemos esta salida   C:\CursoIntroPython-main\Módulo 2 - Crear y administrar proyectos>

# %% [markdown]
# # Ejectuar app.py
#     lo ejecute con el comando python app.py
#     2022-02-20 06:18:21.128470
#     2022-03-27 10:18:21.128470
